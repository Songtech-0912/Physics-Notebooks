# %% [markdown]
# # AP Physics C: Resistance Investigation
#
# **Research Question:** How does current vary with varying resistance and constant voltage?

# %% [markdown]
# ## Data Collection

# %% [markdown]
# A variety of resistors of resistance from 100 Ohms to 500 were used in the investigation. The results were as follows:

# %%
import pandas as pd
import numpy as np

# %%
data = np.array([
    [100, 0.0623],
    [200, 0.0319],
    [300, 0.022],
    [400, 0.0169],
    [500, 0.0137]
])

# %%
df = pd.DataFrame(data, columns = ["Resistance", "Current"])

# %%
df
# Out:
#    Resistance  Current
# 0       100.0   0.0623
# 1       200.0   0.0319
# 2       300.0   0.0220
# 3       400.0   0.0169
# 4       500.0   0.0137

# %%
R = df["Resistance"]
I = df["Current"]

# %%
def reciprocal_model(x, a):
    return a / x

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# A line of best fit was generated by `curve_fit` from SciPy, and plotted in addition to the actual data points collected. A reciprocal model $f(x) = \frac{a}{x}$ was used.

# %%
import plotly.graph_objects as go
from scipy.optimize import curve_fit
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
param, param_cov = curve_fit(reciprocal_model, R, I)

# %%
samples = 160
R_generated = np.linspace(100, 500, num=samples)

# %%
I_best_fit = reciprocal_model(R_generated, param[0])

# %%
fig1 = go.Figure()
fig1.add_trace(go.Scatter(x=R_generated, y=I_best_fit, mode="lines", name="Best fit"))
fig1.add_trace(go.Scatter(x=R, y=I, mode="markers", name="Data values"))
fig1.update_layout(title="Current from Resistance at V = 6")
fig1.update_layout(
    xaxis_title=r"$R (\Omega)$",
    yaxis_title=r"$I (A)$"
)
fig1.show()
# Out:
# <div>                            <div id="c4834b5d-239f-4e9d-bff7-6ffbfa57b2aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4834b5d-239f-4e9d-bff7-6ffbfa57b2aa")) {                    Plotly.newPlot(                        "c4834b5d-239f-4e9d-bff7-6ffbfa57b2aa",                        [{"mode":"lines","name":"Best fit","x":[100.0,102.51572327044025,105.03144654088051,107.54716981132076,110.062893081761,112.57861635220125,115.09433962264151,117.61006289308176,120.12578616352201,122.64150943396226,125.15723270440252,127.67295597484276,130.18867924528303,132.70440251572327,135.22012578616352,137.73584905660377,140.25157232704402,142.7672955974843,145.2830188679245,147.7987421383648,150.31446540880503,152.83018867924528,155.34591194968553,157.86163522012578,160.37735849056605,162.89308176100627,165.40880503144655,167.9245283018868,170.44025157232704,172.9559748427673,175.47169811320754,177.9874213836478,180.50314465408803,183.0188679245283,185.53459119496856,188.0503144654088,190.56603773584905,193.0817610062893,195.59748427672957,198.1132075471698,200.62893081761007,203.14465408805032,205.66037735849056,208.1761006289308,210.69182389937106,213.20754716981133,215.72327044025155,218.23899371069183,220.75471698113208,223.27044025157232,225.78616352201257,228.30188679245282,230.81761006289307,233.33333333333331,235.8490566037736,238.36477987421384,240.88050314465409,243.39622641509433,245.91194968553458,248.42767295597483,250.94339622641508,253.45911949685535,255.9748427672956,258.49056603773585,261.00628930817606,263.52201257861634,266.0377358490566,268.55345911949684,271.0691823899371,273.58490566037733,276.1006289308176,278.6163522012579,281.1320754716981,283.6477987421383,286.1635220125786,288.6792452830189,291.19496855345915,293.71069182389937,296.2264150943396,298.74213836477986,301.25786163522014,303.77358490566036,306.28930817610063,308.80503144654085,311.
777,0.004922600619195046,0.004862385321100918,0.004803625377643505,0.004746268656716418,0.004690265486725663,0.004635568513119534,0.004582132564841498,0.00452991452991453,0.004478873239436619,0.0044289693593314765,0.004380165289256199,0.004332425068119892,0.004285714285714286,0.00424,0.004195250659630606,0.004151436031331592,0.0041085271317829455,0.004066496163682864,0.004025316455696203,0.003984962406015038,0.003945409429280397,0.0039066339066339065,0.0038686131386861315,0.0038313253012048198,0.003794749403341289,0.00375886524822695,0.0037236533957845435,0.0036890951276102087,0.003655172413793104,0.003621867881548975,0.0035891647855530472,0.0035570469798657718,0.0035254988913525505,0.003494505494505495,0.0034640522875816994,0.0034341252699784013,0.003404710920770878,0.0033757961783439493,0.003347368421052632,0.0033194154488517744,0.0032919254658385095,0.0032648870636550306,0.003238289205702648,0.003212121212121212,0.0031863727454909817,0.0031610337972167,0.0031360946745562133,0.003111545988258317,0.003087378640776699,0.0030635838150289015,0.003040152963671128,0.0030170777988614804,0.0029943502824858756,0.00297196261682243,0.0029499072356215217,0.0029281767955801103,0.002906764168190128,0.002885662431941924,0.0028648648648648646,0.0028443649373881934,0.002824156305506217,0.0028042328042328043,0.0027845884413309984,0.0027652173913043482,0.002746113989637306,0.0027272727272727275,0.0027086882453151617,0.0026903553299492387,0.0026722689075630254,0.002654424040066778,0.0026368159203980102,0.0026194398682042835,0.0026022913256955812,0.0025853658536585367,0.0025686591276252017,0.002552166934189406,0.002535885167464115,0.0025198098256735343,0.0025039370078740156,0.0024882629107981225,0.002472783825816485,0.0024574961360123646,0.0024423963133640555,0.0024274809160305345,0.002412746585735964,0.002398190045248869,0.0023838080959520244,0.002369597615499255,0.0023555555555555556,0.002341678939617084,0.00232796486090776,0.002314410480349345,0.002301013024602026,0.002287769784172662,0.002274678111587983,0.0022617354196301565,0.002248939179632249,0.0022362869198312234,0.002223776223776224,0.002211404728789986,0.002199170124481328,0.0021870701513067403,0.0021751025991792066,0.002163265306122449,0.002151556156968877,0.0021399730820995965,0.0021285140562248995,0.0021171770972037286,0.002105960264900662,0.0020948616600790513,0.0020838794233289646,0.0020730117340286834,0.0020622568093385217,0.0020516129032258066,0.0020410783055198976,0.0020306513409961684,0.002020330368487929,0.0020101137800252844,0.002],"y":[0.063232871511074,0.06168114460282679,0.0602037519177291 ...

# %%
param[0]
# Out:
# 6.3232871511074

# %% [markdown]
# Within the model, the parameter used was $a = 6.32$, as compared to an actual nominal value of 6 volts. From the model, it can be deduced that:

# %% [markdown]
# $$
# m = \left(\frac{I_2 - I_1}{\frac{1}{R_2} - \frac{1}{R_1}}
# \right) = 6.32 \, A\Omega = 6.32 \, V
# $$

# %% [markdown]
# $$
# R \propto \frac{1}{I}
# $$

# %% [markdown]
# $$
# R = \frac{a}{I} \Rightarrow R = \frac{V}{I}
# $$

# %% [markdown]
# The percent error from an actual value of V = 6V was calculated as follows:

# %%
def percent_err(expected, actual):
    err = abs(expected - actual) / actual * 100
    return "{:2.1f}%".format(err)

# %%
percent_err(param[0], 6)
# Out:
# '5.4%'

# %% [markdown]
# Thus, it can be seen that results were collected to an accuracy of 5.4%.
